# %%
import requests
import pandas as pd
from datetime import datetime
import time
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
access_token='xxx' 
headers = {'Authorization':"Token "+access_token}

# %%
# loop through all pages to obtain all issues information
# label story point = 1
page_num = 1
issues_l=[]
for page_num in range(1,30):
    try:
        # to find all the repos' names from each page
        url = f"https://api.github.com/search/issues?q=is:issue+archived:false+is:public+label:%22Points:%201%22&page={page_num}"
        issue_l=requests.get(url,headers=headers).json()
        issue_l2=issue_l['items']
        issues_l.append(issue_l2)
    except:
        issues_l.append(None)

# %%
repository=[]
for page in issues_l:
    for issue_l2 in page:
        try:
            repository.append(issue_l2['repository_url'])
        except:
            pass

len(repository)
# Out:
# 870

# %%
#repository

# %%
repository_data=pd.DataFrame()
repository_data['repo_url']=repository

# %%
repository_data
# Out:
#                                               repo_url
# 0    https://api.github.com/repos/center-for-threat...
# 1       https://api.github.com/repos/ColoredCow/portal
# 2    https://api.github.com/repos/CMPUT301W23T23/QRAPP
# 3    https://api.github.com/repos/CMPUT301W23T23/QRAPP
# 4    https://api.github.com/repos/CMPUT301W23T23/QRAPP
# ..                                                 ...
# 865  https://api.github.com/repos/nataliacasanova/i...
# 866  https://api.github.com/repos/ita-social-projec...
# 867  https://api.github.com/repos/ita-social-projec...
# 868  https://api.github.com/repos/ita-social-projec...
# 869  https://api.github.com/repos/PabloCC/iwvg-devo...
#
# [870 rows x 1 columns]

# %%
repository_data.iloc[0]
# Out:
# repo_url    https://api.github.com/repos/center-for-threat...
# Name: 0, dtype: object

# %%
repository_data_name = repository_data["repo_url"].str.split("/", n = 4, expand = True)
repository_data_name
# Out:
#           0 1                2      3  \
# 0    https:     api.github.com  repos
# 1    https:     api.github.com  repos
# 2    https:     api.github.com  repos
# 3    https:     api.github.com  repos
# 4    https:     api.github.com  repos
# ..      ... ..             ...    ...
# 865  https:     api.github.com  repos
# 866  https:     api.github.com  repos
# 867  https:     api.github.com  repos
# 868  https:     api.github.com  repos
# 869  https:     api.github.com  repos
#
#                                                      4
# 0    center-for-threat-informed-defense/attack-work...
# 1                                    ColoredCow/portal
# 2                                 CMPUT301W23T23/QRAPP
# 3                                 CMPUT301W23T23/QRAPP
# 4                                 CMPUT301W23T23/QRAPP
# ..                                                 ...
# 865       nataliacasanova/imvg-devops-casanova-natalia
# 866                      ita-social-projects/GreenCity
# 867                      ita-social-projects/GreenCity
# 868                      ita-social-projects/GreenCity
# 869                 PabloCC/iwvg-devops-pablo-coronado
#
# [870 rows x 5 columns]

# %%
repository_data_name.drop(columns=repository_data_name.columns[0], axis=1, inplace=True)
repository_data_name.drop(columns=repository_data_name.columns[0], axis=1, inplace=True)
repository_data_name.drop(columns=repository_data_name.columns[0], axis=1, inplace=True)
repository_data_name.drop(columns=repository_data_name.columns[0], axis=1, inplace=True)
repository_data_name = repository_data_name.drop_duplicates()
repository_data_name
# Out:
#                                                      4
# 0    center-for-threat-informed-defense/attack-work...
# 1                                    ColoredCow/portal
# 2                                 CMPUT301W23T23/QRAPP
# 6                 KA-devl/VueLovers-soen341project2023
# 11            Kenny-Tinoco/galy-studio-web-system.back
# ..                                                 ...
# 841                walericalupm/iwvg-devops-eric-aldas
# 849       nataliacasanova/imvg-devops-casanova-natalia
# 852                     lconder/iwvg-devops-luis-conde
# 854                   jordyxt/iwvg-devops-jordy-arrese
# 869                 PabloCC/iwvg-devops-pablo-coronado
#
# [88 rows x 1 columns]

# %%
# loop through all pages to obtain all issues information
issues=[]
for page_num in range(25):
    for r in range(repository_data_name.shape[0]):
        repository_i = repository_data_name.iloc[r,0]
        try:
            # to find all the repos' names from each page
            url = f"https://api.github.com/repos/{repository_i}/issues?state=all&page={page_num}"
            issue=requests.get(url,headers=headers).json()
            issues.append(issue)
        except:
            issues.append(None)

# %%
repo_url=[]
for page in issues:
    for issue in page:
        try:
            repo_url.append(issue['repository_url'])
        except:
            pass
len(repo_url)
# Out:
# 9929

# %%
issue_number=[]
for page in issues:
    for issue in page:
        try:
            issue_number.append(issue['number'])
        except:
            pass
len(issue_number)
# Out:
# 9929

# %%
issue_title=[]
for page in issues:
    for issue in page:
        try:
            issue_title.append(issue['title'])
        except:
            pass
len(issue_title)
# Out:
# 9929

# %%
issue_body=[]
for page in issues:
    for issue in page:
        try:
            issue_body.append(issue['body'])
        except:
            pass
len(issue_body)
# Out:
# 9929

# %%
issue_state=[]
for page in issues:
    for issue in page:
        try:
            issue_state.append(issue['state'])
        except:
            pass
len(issue_state)
# Out:
# 9929

# %%
issue_create_time=[]
for page in issues:
    for issue in page:
        try:
            issue_create_time.append(issue['created_at'])
        except:
            pass
len(issue_create_time)
# Out:
# 9929

# %%
issue_update_time=[]
for page in issues:
    for issue in page:
        try:
            issue_update_time.append(issue['updated_at'])
        except:
            pass
len(issue_update_time)
# Out:
# 9929

# %%
issue_close_time=[]
for page in issues:
    for issue in page:
        try:
            issue_close_time.append(issue['closed_at'])
        except:
            pass
len(issue_close_time)
# Out:
# 9929

# %%
issue_pull_request=[]
for page in issues:
    for issue in page:
        try:
            issue_pull_request.append(issue['pull_request'])
        except:
            issue_pull_request.append('not_pull_request')
len(issue_pull_request)
# Out:
# 9929

# %%
issue_label=[]
for page in issues:
    for issue in page:
        try:
            issue_label.append(issue['labels'])
        except:
            pass
len(issue_label)
# Out:
# 9929

# %%
issue_data=pd.DataFrame()
issue_data['repo_url']=repo_url
issue_data['issue_number']=issue_number
issue_data['issue_title']=issue_title
issue_data['issue_body']=issue_body
issue_data['issue_state']=issue_state
issue_data['issue_created_at']=issue_create_time
issue_data['issue_created_at_timestamp']=issue_create_time
issue_data['issue_updated_at']=issue_update_time
issue_data['issue_updated_at_timestamp']=issue_update_time
issue_data['issue_closed_at']=issue_close_time
issue_data['issue_closed_at_timestamp']=issue_close_time
issue_data['resolution_time']=np.nan
issue_data['issue_pull_request']=issue_pull_request
issue_data['issue_label']=issue_label
issue_data['issue_label_name']=issue_label
issue_data=issue_data.reset_index().drop(columns='index')

# %%
issue_data
# Out:
#                                                repo_url  issue_number  \
# 0     https://api.github.com/repos/center-for-threat...           444
# 1     https://api.github.com/repos/center-for-threat...           443
# 2     https://api.github.com/repos/center-for-threat...           442
# 3     https://api.github.com/repos/center-for-threat...           441
# 4     https://api.github.com/repos/center-for-threat...           440
# ...                                                 ...           ...
# 9924          https://api.github.com/repos/Kitware/dive           620
# 9925          https://api.github.com/repos/Kitware/dive           619
# 9926          https://api.github.com/repos/Kitware/dive           618
# 9927          https://api.github.com/repos/Kitware/dive           617
# 9928          https://api.github.com/repos/Kitware/dive           616
#
#                                             issue_title  \
# 0                                 update popover syntax
# 1                   Support for Mobile/ICS Data Sources
# 2     ngx-smart-popover syntax conflicts with new Ch...
# 3     Bump http-cache-semantics and @angular/cli in ...
# 4                         Bug: unable to docker-compose
# ...                                                 ...
# 9924                                      3 Column View
# 9925                   Fix annotator creation mode bugs
# 9926                       Refactor/detections fetching
# 9927                             Attributes CSV loading
# 9928                                  Upgrade pipelines
#
#                                              issue_body issue_state  \
# 0                                        Resolves #442       closed
# 1                                        Resolves #428       closed
# 2     Since the latest update, Chrome throws an erro...      closed
# 3     Bumps [http-cache-semantics](https://github.co...        open
# 4     Hi there,\r\nI'm trying to set up the workbenc...      closed
# ...                                                 ...         ...
# 9924  Related to #614 but much less invasive.\r\n\r\...      closed
# 9925  Several issues.  \r\n\r\n* [minor] Reverted `c...      closed
# 9926  Refactor the sorta messy girder queries for de...      closed
# 9927  On reading of a CSV file it will inline calcul...      closed
# 9928  supercedes #574 \r\n\r\n* Reduce worker image ...      closed
#
#           issue_created_at issue_created_at_timestamp      issue_updated_at  \
# 0     2023-02-27T15:43:35Z       2023-02-27T15:43:35Z  2023-02-27T15:44:39Z
# 1     2023-02-17T18:35:49Z       2023-02-17T18:35:49Z  2023-02-23T18:34:09Z
# 2     2023-02-17T16:11:31Z       2023-02-17T16:11:31Z  2023-02-27T15:45:03Z
# 3     2023-02-03T00:39:05Z       2023-02-03T00:39:05Z  2023-02-03T00:40:26Z
# 4     2023-01-31T15:23:18Z       2023-01-31T15:23:18Z  2023-01-31T18:28:39Z
# ...                    ...                        ...                   ...
# 9924  2021-03-08T02:39:40Z       2021-03-08T02:39:40Z  2021-09-21T19:24:22Z
# 9925  2021-03-06T03:54:53Z       2021-03-06T03:54:53Z  2021-03-08T16:25:55Z
# 9926  2021-03-05T19:28:31Z       2021-03-05T19:28:31Z  2021-03-11T22:09:39Z
# 9927  2021-03-05T19:17:36Z       2021-03-05T19:17:36Z  2021-03-29T12:07:04Z
# 9928  2021-03-05T02:59:11Z       2021-03-05T02:59:11Z  2021-03-11T13:01:07Z
#
#      issue_updated_at_timestamp       issue_closed_at  \
# 0          2023-02-27T15:44:39Z  2023-02-27T15:44:35Z
# 1          2023-02-23T18:34:09Z  2023-02-23T18:34:04Z
# 2          2023-02-27T15:45:03Z  2023-02-27T15:45:03Z
# 3          2023-02-03T00:40:26Z                  None
# 4          2023-01-31T18:28:39Z  2023-01-31T15:33:40Z
# ...                         ...                   ...
# 9924       2021-09-21T19:24:22Z  2021-08-19T18:21:01Z
# 9925       2021-03-08T16:25:55Z  2021-03-08T16:25:53Z
# 9926       2021-03-11T22:09:39Z  2021-03-11T22:09:37Z
# 9927       2021-03-29T12:07:04Z  2021-03-23T16:54:12Z
# 9928       2021-03-11T13:01:07Z  2021-03-11T13:01:03Z
#
#      issue_closed_at_timestamp  resolution_time  \
# 0         2023-02-27T15:44:35Z              NaN
# 1         2023-02-23T18:34:04Z              NaN
# 2         2023-02-27T15:45:03Z              NaN
# 3                         None              NaN
# 4         2023-01-31T15:33:40Z              NaN
# ...                        ...              ...
# 9924      2021-08-19T18:21:01Z              NaN
# 9925      2021-03-08T16:25:53Z              NaN
# 9926      2021-03-11T22:09:37Z              NaN
# 9927      2021-03-23T16:54:12Z              NaN
# 9928      2021-03-11T13:01:03Z              NaN
#
#                                      issue_pull_request  \
# 0     {'url': 'https://api.github.com/repos/center-f...
# 1     {'url': 'https://api.github.com/repos/center-f...
# 2                                      not_pull_request
# 3     {'url': 'https://api.github.com/repos/center-f...
# 4                                      not_pull_request
# ...                                                 ...
# 9924  {'url': 'https://api.github.com/repos/Kitware/...
# 9925  {'url': 'https://api.github.com/repos/Kitware/...
# 9926  {'url': 'https://api.github.com/repos/Kitware/...
# 9927  {'url': 'https://api.github.com/repos/Kitware/...
# 9928  {'url': 'https://api.github.com/repos/Kitware/...
#
#                                             issue_label  \
# 0                                                    []
# 1                                                    []
# 2     [{'id': 1862294612, 'node_id': 'MDU6TGFiZWwxOD...
# 3     [{'id': 3822113702, 'node_id': 'LA_kwDODm7gMc7...
# 4                                                    []
# ...                                                 ...
# 9924  [{'id': 1652276509, 'node_id': 'MDU6TGFiZWwxNj...
# 9925  [{'id': 2788995153, 'node_id': 'MDU6TGFiZWwyNz...
# 9926                                                 []
# 9927                                                 []
# 9928                                                 []
#
#                                        issue_label_name
# 0                                                    []
# 1                                                    []
# 2     [{'id': 1862294612, 'node_id': 'MDU6TGFiZWwxOD...
# 3     [{'id': 3822113702, 'node_id': 'LA_kwDODm7gMc7...
# 4                                                    []
# ...                                                 ...
# 9924  [{'id': 1652276509, 'node_id': 'MDU6TGFiZWwxNj...
# 9925  [{'id': 2788995153, 'node_id': 'MDU6TGFiZWwyNz...
# 9926                                                 []
# 9927                                                 []
# 9928                                                 []
#
# [9929 rows x 15 columns]

# %%
j = 0
for j in range(issue_data.shape[0]):
    issue_data.iloc[j,6] = datetime.strptime(issue_data.iloc[j,5], '%Y-%m-%dT%H:%M:%SZ')
    issue_data.iloc[j,8] = datetime.strptime(issue_data.iloc[j,7], '%Y-%m-%dT%H:%M:%SZ')
    if issue_data.iloc[j,4] == 'closed':
        issue_data.iloc[j,10] = datetime.strptime(issue_data.iloc[j,9], '%Y-%m-%dT%H:%M:%SZ')

# %%
j = 0
for j in range(issue_data.shape[0]):
    if len(issue_data.iloc[j,13]) == 0:
        issue_data.iloc[j,14] = 'no_label'
    else:
        multi_labels = []
        k = 0
        label1 = issue_data.iloc[j,13]
        for k in range(len(issue_data.iloc[j,14])):
            x = label1[k]['name']
            multi_labels += [x]
            # print(multi_labels)
            # print(k)
        issue_data.iloc[j,14] = str(multi_labels)

# %%
j = 0
for j in range(issue_data.shape[0]):
    if issue_data.iloc[j,12] != 'not_pull_request': 
        issue_data.iloc[j,12] = 'pull_request'

# %%
issue_data.to_excel('label_points_1_issues.xlsx')

# %%
issue_data_closed = issue_data.dropna(subset = ['issue_closed_at'])

# %%
j = 0
for j in range(issue_data_closed.shape[0]):
    issue_data_closed.iloc[j,11] = ((issue_data_closed.iloc[j,10] - issue_data_closed.iloc[j,6]).total_seconds())/(24*60*60)

# %%
issue_data_closed.to_excel('label_points_1_issues_closed.xlsx')

# %%
issue_data_closed
# Out:
#                                                repo_url  issue_number  \
# 0     https://api.github.com/repos/center-for-threat...           444
# 1     https://api.github.com/repos/center-for-threat...           443
# 2     https://api.github.com/repos/center-for-threat...           442
# 4     https://api.github.com/repos/center-for-threat...           440
# 6     https://api.github.com/repos/center-for-threat...           438
# ...                                                 ...           ...
# 9924          https://api.github.com/repos/Kitware/dive           620
# 9925          https://api.github.com/repos/Kitware/dive           619
# 9926          https://api.github.com/repos/Kitware/dive           618
# 9927          https://api.github.com/repos/Kitware/dive           617
# 9928          https://api.github.com/repos/Kitware/dive           616
#
#                                             issue_title  \
# 0                                 update popover syntax
# 1                   Support for Mobile/ICS Data Sources
# 2     ngx-smart-popover syntax conflicts with new Ch...
# 4                         Bug: unable to docker-compose
# 6     Fix bug with setting light/dark mode from syst...
# ...                                                 ...
# 9924                                      3 Column View
# 9925                   Fix annotator creation mode bugs
# 9926                       Refactor/detections fetching
# 9927                             Attributes CSV loading
# 9928                                  Upgrade pipelines
#
#                                              issue_body issue_state  \
# 0                                        Resolves #442       closed
# 1                                        Resolves #428       closed
# 2     Since the latest update, Chrome throws an erro...      closed
# 4     Hi there,\r\nI'm trying to set up the workbenc...      closed
# 6     Sets the theme class on the overlay container ...      closed
# ...                                                 ...         ...
# 9924  Related to #614 but much less invasive.\r\n\r\...      closed
# 9925  Several issues.  \r\n\r\n* [minor] Reverted `c...      closed
# 9926  Refactor the sorta messy girder queries for de...      closed
# 9927  On reading of a CSV file it will inline calcul...      closed
# 9928  supercedes #574 \r\n\r\n* Reduce worker image ...      closed
#
#           issue_created_at issue_created_at_timestamp      issue_updated_at  \
# 0     2023-02-27T15:43:35Z        2023-02-27 15:43:35  2023-02-27T15:44:39Z
# 1     2023-02-17T18:35:49Z        2023-02-17 18:35:49  2023-02-23T18:34:09Z
# 2     2023-02-17T16:11:31Z        2023-02-17 16:11:31  2023-02-27T15:45:03Z
# 4     2023-01-31T15:23:18Z        2023-01-31 15:23:18  2023-01-31T18:28:39Z
# 6     2023-01-26T17:07:48Z        2023-01-26 17:07:48  2023-01-27T15:40:13Z
# ...                    ...                        ...                   ...
# 9924  2021-03-08T02:39:40Z        2021-03-08 02:39:40  2021-09-21T19:24:22Z
# 9925  2021-03-06T03:54:53Z        2021-03-06 03:54:53  2021-03-08T16:25:55Z
# 9926  2021-03-05T19:28:31Z        2021-03-05 19:28:31  2021-03-11T22:09:39Z
# 9927  2021-03-05T19:17:36Z        2021-03-05 19:17:36  2021-03-29T12:07:04Z
# 9928  2021-03-05T02:59:11Z        2021-03-05 02:59:11  2021-03-11T13:01:07Z
#
#      issue_updated_at_timestamp       issue_closed_at  \
# 0           2023-02-27 15:44:39  2023-02-27T15:44:35Z
# 1           2023-02-23 18:34:09  2023-02-23T18:34:04Z
# 2           2023-02-27 15:45:03  2023-02-27T15:45:03Z
# 4           2023-01-31 18:28:39  2023-01-31T15:33:40Z
# 6           2023-01-27 15:40:13  2023-01-27T15:40:07Z
# ...                         ...                   ...
# 9924        2021-09-21 19:24:22  2021-08-19T18:21:01Z
# 9925        2021-03-08 16:25:55  2021-03-08T16:25:53Z
# 9926        2021-03-11 22:09:39  2021-03-11T22:09:37Z
# 9927        2021-03-29 12:07:04  2021-03-23T16:54:12Z
# 9928        2021-03-11 13:01:07  2021-03-11T13:01:03Z
#
#      issue_closed_at_timestamp  resolution_time issue_pull_request  \
# 0          2023-02-27 15:44:35         0.000694       pull_request
# 1          2023-02-23 18:34:04         5.998785       pull_request
# 2          2023-02-27 15:45:03         9.981620   not_pull_request
# 4          2023-01-31 15:33:40         0.007199   not_pull_request
# 6          2023-01-27 15:40:07         0.939109       pull_request
# ...                        ...              ...                ...
# 9924       2021-08-19 18:21:01       164.653715       pull_request
# 9925       2021-03-08 16:25:53         2.521528       pull_request
# 9926       2021-03-11 22:09:37         6.111875       pull_request
# 9927       2021-03-23 16:54:12        17.900417       pull_request
# 9928       2021-03-11 13:01:03         6.417963       pull_request
#
#                                             issue_label  \
# 0                                                    []
# 1                                                    []
# 2     [{'id': 1862294612, 'node_id': 'MDU6TGFiZWwxOD...
# 4                                                    []
# 6                                                    []
# ...                                                 ...
# 9924  [{'id': 1652276509, 'node_id': 'MDU6TGFiZWwxNj...
# 9925  [{'id': 2788995153, 'node_id': 'MDU6TGFiZWwyNz...
# 9926                                                 []
# 9927                                                 []
# 9928                                                 []
#
#                issue_label_name
# 0                      no_label
# 1                      no_label
# 2          ['bug', 'Points: 1']
# 4                      no_label
# 6                      no_label
# ...                         ...
# 9924  ['Type: Feature Request']
# 9925       ['skipped-planning']
# 9926                   no_label
# 9927                   no_label
# 9928                   no_label
#
# [7692 rows x 15 columns]
